# %% [markdown]
# <a href="https://colab.research.google.com/github/b21892757/globalai-project/blob/main/hw1_studentDF.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
d={}
studentName=[]
studentAge=[]
studentNumber=[]
studentLesson=[]
studentGrade =[]
global df 
df= pd.DataFrame(d)
df=df.assign(StudentName = studentName,StudentAge=studentAge, StudentNumber=studentNumber,StudentLesson=studentLesson,StudentGrade=studentGrade)

# %%
def ogrenciEkle(df):
  isim = input("İsim giriniz : ")
  yas = input("Yaş giriniz : ")
  isInteger = True
  while(isInteger):
      try:
          yas = int(yas)
          isInteger = False
      except ValueError:
          yas = input("Lütfen Sayı Türünde Bir Değer Giriniz \nYaş giriniz : ")
      
  #while type(int(yas))==str:
  #  yas = int(input("Lütfen Sayı Türünde Bir Değer Giriniz \nYaş giriniz : "))
 
  okulNo =int(input("Okul Numaranızı giriniz : "))
  while 1000 > okulNo <5000:
        okulNo =int(input("Lütfen 1000-5000 Arasında Bir Numara Girişi Yapınız \nOkul Numaranızı giriniz : "))
  if (df['StudentNumber']==okulNo).any() :
    print("Mevcut Bir Numara Girişi Yapılmaya Çalıştın! Lütfen Tekrar Numara Giriniz! ")
    okulNo =int(input("Okul Numaranızı giriniz : "))
  
  dersAdi="Linear Algebra"
  
  puan = int(input("Notunuzu giriniz: "))
  while 0 > puan > 100 :
    puan = int(input("Lütfen 0-100 Arasında Bir Not Girişi Yapınız \nNotunuzu giriniz: ")) 

  df=aktar(df,isim,yas,okulNo,dersAdi,puan)
  return df

# %%
def aktar(df,isim,yas,okulNo,dersAdi,puan):
  studentName.append(isim)
  studentAge.append(yas)
  studentNumber.append(okulNo)
  studentLesson.append(dersAdi)
  studentGrade.append(puan)
  ogr = {
      "StudentName": [isim],
      "StudentAge": [yas],
      "StudentNumber":[okulNo],
      "StudentLesson":[dersAdi],
      "StudentGrade":[puan]
    }
  data = pd.DataFrame(ogr)
  df = df.append(data)
  return df

# %%
def menu(df):
  status=True
  while status:
    print("""
    1) Öğrenci Ekle
    2) Öğrenci Sorgula
    3) Bütün Öğrencileri Göster
    4) Öğrencilerin Harf Notunu Göster
    5) Öğrencilerin Kaldı/Geçti Durumunu Sorgula
    6) En Yüksek Nota Sahip Öğrenciyi Ekrana Yazdır
    7) En Düşük Nota Sahip Öğrenciyi Ekrana Yazdır
    8) Sınıfın Not Ortalamasını Yazdır
    9) Öğrencileri Alfabetik Sırala
    10) Uygulamayı Kapat\n""")
    chosen = int(input("Seçim yapınız : "))
    if chosen == 1:
     df=ogrenciEkle(df)
     print("\nÖğrenci Başarıyla Eklendi.\n")
    if chosen == 2:
      studentNo=int(input("Öğrenci Numarasını Giriniz : "))
      print(df[df['StudentNumber'] == studentNo])
    if chosen == 3:
      print("\nÖğrenci Listeniz Başarıyla Ekrana Getirildi.\n")
      print(df)
    if chosen == 4:
      df['Harf'] = np.where((df.StudentGrade < 60 ), 
            'F', np.where((df.StudentGrade >= 60) & (df.StudentGrade <= 69),  
            'D', np.where((df.StudentGrade >= 70) & (df.StudentGrade <= 79), 
            'C', np.where((df.StudentGrade >= 80) & (df.StudentGrade <= 89), 
            'B', np.where((df.StudentGrade >= 90) & (df.StudentGrade <= 100), 
            'A', 'No Marks')))))
      print("\nHarf Notları Başarıyla Güncellendi\n")
      print(df)
    if chosen == 5:
      df['Kaldimi'] = np.where((df.Harf == 'F' ), 
                  'Kaldi', np.where((df.Harf != 'F'),  
                  'Geçti', 'No Marks'))
      print(df)
      print("\nKalan/Geçen Listesi Başarıyla Güncellendi.\n")
    if chosen == 6 :
      print(f"\nEn Yüksek Nota Sahip Öğrenci\n : {df[df.StudentGrade.max() == df['StudentGrade']]}")
    if chosen == 7 :
      print(f"\nEn Düşük Nota Sahip Öğrenci\n : {df[df.StudentGrade.min() == df['StudentGrade']]}")
    if chosen == 8:
      meanTotal= df["StudentGrade"].mean()
      print(f"\nSınıfın Not Ortalaması : {meanTotal}")
    if chosen == 9:
      print(df.sort_values(["StudentName"], ascending=True))
    if chosen == 10:
      print("\nProgram Kapatılıyor.....\n")
      status=False

# %%
menu(df)
# Out:
#     1) Öğrenci Ekle
#     2) Öğrenci Sorgula
#     3) Bütün Öğrencileri Göster
#     4) Öğrencilerin Harf Notunu Göster
#     5) Öğrencilerin Kaldı/Geçti Durumunu Sorgula
#     6) En Yüksek Nota Sahip Öğrenciyi Ekrana Yazdır
#     7) En Düşük Nota Sahip Öğrenciyi Ekrana Yazdır
#     8) Sınıfın Not Ortalamasını Yazdır
#     9) Öğrencileri Alfabetik Sırala
#     10) Uygulamayı Kapat
#
# Seçim yapınız : 1
# İsim giriniz : Ayşe
# Yaş giriniz : a
# Lütfen Sayı Türünde Bir Değer Giriniz
# Yaş giriniz : 20
# Okul Numaranızı giriniz : 100
# Lütfen 1000-5000 Arasında Bir Numara Girişi Yapınız
# Okul Numaranızı giriniz : 1600
# Notunuzu giriniz: 65
#
# Öğrenci Başarıyla Eklendi.
#
#
#     1) Öğrenci Ekle
#     2) Öğrenci Sorgula
#     3) Bütün Öğrencileri Göster
#     4) Öğrencilerin Harf Notunu Göster
#     5) Öğrencilerin Kaldı/Geçti Durumunu Sorgula
#     6) En Yüksek Nota Sahip Öğrenciyi Ekrana Yazdır
#     7) En Düşük Nota Sahip Öğrenciyi Ekrana Yazdır
#     8) Sınıfın Not Ortalamasını Yazdır
#     9) Öğrencileri Alfabetik Sırala
#     10) Uygulamayı Kapat
#
# Seçim yapınız : 1
# İsim giriniz : ali
# Yaş giriniz : 20
# Okul Numaranızı giriniz : 1650
# Notunuzu giriniz: 70
#
# Öğrenci Başarıyla Eklendi.
#
#
#     1) Öğrenci Ekle
#     2) Öğrenci Sorgula
#     3) Bütün Öğrencileri Göster
#     4) Öğrencilerin Harf Notunu Göster
#     5) Öğrencilerin Kaldı/Geçti Durumunu Sorgula
#     6) En Yüksek Nota Sahip Öğrenciyi Ekrana Yazdır
#     7) En Düşük Nota Sahip Öğrenciyi Ekrana Yazdır
#     8) Sınıfın Not Ortalamasını Yazdır
#     9) Öğrencileri Alfabetik Sırala
#     10) Uygulamayı Kapat
#
# Seçim yapınız : 1
# İsim giriniz : osman
# Yaş giriniz : 20
# Okul Numaranızı giriniz : 1698
# Notunuzu giriniz: 15
#
# Öğrenci Başarıyla Eklendi.
#
#
#     1) Öğrenci Ekle
#     2) Öğrenci Sorgula
#     3) Bütün Öğrencileri Göster
#     4) Öğrencilerin Harf Notunu Göster
#     5) Öğrencilerin Kaldı/Geçti Durumunu Sorgula
#     6) En Yüksek Nota Sahip Öğrenciyi Ekrana Yazdır
#     7) En Düşük Nota Sahip Öğrenciyi Ekrana Yazdır
#     8) Sınıfın Not Ortalamasını Yazdır
#     9) Öğrencileri Alfabetik Sırala
#     10) Uygulamayı Kapat
#
# Seçim yapınız : 3
#
# Öğrenci Listeniz Başarıyla Ekrana Getirildi.
#
#   StudentName  StudentAge  StudentNumber   StudentLesson  StudentGrade
# 0        Ayşe        20.0         1600.0  Linear Algebra          65.0
# 0         ali        20.0         1650.0  Linear Algebra          70.0
# 0       osman        20.0         1698.0  Linear Algebra          15.0
#
#     1) Öğrenci Ekle
#     2) Öğrenci Sorgula
#     3) Bütün Öğrencileri Göster
#     4) Öğrencilerin Harf Notunu Göster
#     5) Öğrencilerin Kaldı/Geçti Durumunu Sorgula
#     6) En Yüksek Nota Sahip Öğrenciyi Ekrana Yazdır
#     7) En Düşük Nota Sahip Öğrenciyi Ekrana Yazdır
#     8) Sınıfın Not Ortalamasını Yazdır
#     9) Öğrencileri Alfabetik Sırala
#     10) Uygulamayı Kapat
#
# Seçim yapınız : 2
# Öğrenci Numarasını Giriniz : 1698
#   StudentName  StudentAge  StudentNumber   StudentLesson  StudentGrade
# 0       osman        20.0         1698.0  Linear Algebra          15.0
#
#     1) Öğrenci Ekle
#     2) Öğrenci Sorgula
#     3) Bütün Öğrencileri Göster
#     4) Öğrencilerin Harf Notunu Göster
#     5) Öğrencilerin Kaldı/Geçti Durumunu Sorgula
#     6) En Yüksek Nota Sahip Öğrenciyi Ekrana Yazdır
#     7) En Düşük Nota Sahip Öğrenciyi Ekrana Yazdır
#     8) Sınıfın Not Ortalamasını Yazdır
#     9) Öğrencileri Alfabetik Sırala
#     10) Uygulamayı Kapat
#
# Seçim yapınız : 4
#
# Harf Notları Başarıyla Güncellendi
#
#   StudentName  StudentAge  StudentNumber   StudentLesson  StudentGrade Harf
# 0        Ayşe        20.0         1600.0  Linear Algebra          65.0    D
# 0         ali        20.0         1650.0  Linear Algebra          70.0    C
# 0       osman        20.0         1698.0  Linear Algebra          15.0    F
#
#     1) Öğrenci Ekle
#     2) Öğrenci Sorgula
#     3) Bütün Öğrencileri Göster
#     4) Öğrencilerin Harf Notunu Göster
#     5) Öğrencilerin Kaldı/Geçti Durumunu Sorgula
#     6) En Yüksek Nota Sahip Öğrenciyi Ekrana Yazdır
#     7) En Düşük Nota Sahip Öğrenciyi Ekrana Yazdır
#     8) Sınıfın Not Ortalamasını Yazdır
#     9) Öğrencileri Alfabetik Sırala
#     10) Uygulamayı Kapat
#
# Seçim yapınız : 5
#   StudentName  StudentAge  StudentNumber   StudentLesson  StudentGrade Harf  \
# 0        Ayşe        20.0         1600.0  Linear Algebra          65.0    D
# 0         ali        20.0         1650.0  Linear Algebra          70.0    C
# 0       osman        20.0         1698.0  Linear Algebra          15.0    F
#
#   Kaldimi
# 0   Geçti
# 0   Geçti
# 0   Kaldi
#
# Kalan/Geçen Listesi Başarıyla Güncellendi.
#
#
#     1) Öğrenci Ekle
#     2) Öğrenci Sorgula
#     3) Bütün Öğrencileri Göster
#     4) Öğrencilerin Harf Notunu Göster
#     5) Öğrencilerin Kaldı/Geçti Durumunu Sorgula
#     6) En Yüksek Nota Sahip Öğrenciyi Ekrana Yazdır
#     7) En Düşük Nota Sahip Öğrenciyi Ekrana Yazdır
#     8) Sınıfın Not Ortalamasını Yazdır
#     9) Öğrencileri Alfabetik Sırala
#     10) Uygulamayı Kapat
#
# Seçim yapınız : 6
#
# En Yüksek Nota Sahip Öğrenci
#  :   StudentName  StudentAge  StudentNumber   StudentLesson  StudentGrade Harf  \
# 0         ali        20.0         1650.0  Linear Algebra          70.0    C
#
#   Kaldimi
# 0   Geçti
#
#     1) Öğrenci Ekle
#     2) Öğrenci Sorgula
#     3) Bütün Öğrencileri Göster
#     4) Öğrencilerin Harf Notunu Göster
#     5) Öğrencilerin Kaldı/Geçti Durumunu Sorgula
#     6) En Yüksek Nota Sahip Öğrenciyi Ekrana Yazdır
#     7) En Düşük Nota Sahip Öğrenciyi Ekrana Yazdır
#     8) Sınıfın Not Ortalamasını Yazdır
#     9) Öğrencileri Alfabetik Sırala
#     10) Uygulamayı Kapat
#
# Seçim yapınız : 7
#
# En Düşük Nota Sahip Öğrenci
#  :   StudentName  StudentAge  StudentNumber   StudentLesson  StudentGrade Harf  \
# 0       osman        20.0         1698.0  Linear Algebra          15.0    F
#
#   Kaldimi
# 0   Kaldi
#
#     1) Öğrenci Ekle
#     2) Öğrenci Sorgula
#     3) Bütün Öğrencileri Göster
#     4) Öğrencilerin Harf Notunu Göster
#     5) Öğrencilerin Kaldı/Geçti Durumunu Sorgula
#     6) En Yüksek Nota Sahip Öğrenciyi Ekrana Yazdır
#     7) En Düşük Nota Sahip Öğrenciyi Ekrana Yazdır
#     8) Sınıfın Not Ortalamasını Yazdır
#     9) Öğrencileri Alfabetik Sırala
#     10) Uygulamayı Kapat
#
# Seçim yapınız : 8
#
# Sınıfın Not Ortalaması : 50.0
#
#     1) Öğrenci Ekle
#     2) Öğrenci Sorgula
#     3) Bütün Öğrencileri Göster
#     4) Öğrencilerin Harf Notunu Göster
#     5) Öğrencilerin Kaldı/Geçti Durumunu Sorgula
#     6) En Yüksek Nota Sahip Öğrenciyi Ekrana Yazdır
#     7) En Düşük Nota Sahip Öğrenciyi Ekrana Yazdır
#     8) Sınıfın Not Ortalamasını Yazdır
#     9) Öğrencileri Alfabetik Sırala
#     10) Uygulamayı Kapat
#
# Seçim yapınız : 9
#   StudentName  StudentAge  StudentNumber   StudentLesson  StudentGrade Harf  \
# 0        Ayşe        20.0         1600.0  Linear Algebra          65.0    D
# 0         ali        20.0         1650.0  Linear Algebra          70.0    C
# 0       osman        20.0         1698.0  Linear Algebra          15.0    F
#
#   Kaldimi
# 0   Geçti
# 0   Geçti
# 0   Kaldi
#
#     1) Öğrenci Ekle
#     2) Öğrenci Sorgula
#     3) Bütün Öğrencileri Göster
#     4) Öğrencilerin Harf Notunu Göster
#     5) Öğrencilerin Kaldı/Geçti Durumunu Sorgula
#     6) En Yüksek Nota Sahip Öğrenciyi Ekrana Yazdır
#     7) En Düşük Nota Sahip Öğrenciyi Ekrana Yazdır
#     8) Sınıfın Not Ortalamasını Yazdır
#     9) Öğrencileri Alfabetik Sırala
#     10) Uygulamayı Kapat
#
# Seçim yapınız : 10
#
# Program Kapatılıyor.....
